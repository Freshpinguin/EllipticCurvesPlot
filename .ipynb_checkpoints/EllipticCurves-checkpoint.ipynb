# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
# Calculate coressponding y value for given x 
def curve(a,b,x):
    y = math.sqrt(pow(x,3)+a*x+b)
    return y


def wrongb(a):
    return math.sqrt(-(4/27)*pow(a,3))


def calcllienareq(x1,y1,x)

# %%
plt.rcParams["figure.figsize"] = (20,10)

a = -3
b = 3 
x1 = 0
y1 = curve(a,b,0)

x2 = 2
y2 = curve(a,b,2)

m = (y2 - y1)/(x2-x1)
t = y1 - m * x1

x3 = pow(m,2) - x1 - x2
y3 = curve(a,b,x3)

y, x = np.ogrid[-5:5:100j, -5:5:100j]




plt.contour(x.ravel(), y.ravel(), pow(y, 2) - pow(x, 3) - x * a - b, [0], linewidths=6, colors='green')
plt.contour(x.ravel(),y.ravel(), y-m*x-t, [0], colors="red")
plt.plot(x1,y1, marker='o',markersize=15)
plt.plot(x2,y2, marker='o',markersize=15)
plt.plot(x3,y3, marker='o',markersize=15)
plt.plot(x2,-y2, marker='o',markersize=15)
plt.plot([x2,x2],[5,-5])
plt.grid()
plt.show()
#plt.title("x*x + y*y = 4")
#plt.savefig('./Downloads/addition.png',dpi=400)

# %%
plt.rcParams["figure.figsize"] = (20,10)

a = -3
b = 3 
x1 = 0
y1 = curve(a,b,0)

x2 = -1.2
y2 = curve(a,b,2)

m = (3*pow(x2,2) + a)/(2*y2)
t = y2 - m * x2

x3 = pow(m,2) - x2 - x2
y3 = curve(a,b,x3)

y, x = np.ogrid[-5:5:100j, -5:5:100j]
#plt.contour(x.ravel(), y.ravel(), pow(y, 2) - pow(x, 3) - x * a - b, [0], linewidths=6)


#plt.contour(x.ravel(), y.ravel(), pow(x,2) + pow(y,2), [4], linewidths=6, colors='red')



plt.contour(x.ravel(), y.ravel(), pow(y, 2) - pow(x, 3) - x * a - b, [0], linewidths=6, colors='green')
plt.contour(x.ravel(),y.ravel(), y-m*x-t, [0], colors="red")
#plt.plot(x1,y1, marker='o',markersize=15)
plt.plot(x2,y2, marker='o',markersize=15)
plt.plot(x3,y3, marker='o',markersize=15)
plt.plot(x3,-y3, marker='o',markersize=15)
plt.plot([x3,x3],[5,-5])
plt.grid()
#plt.show()
#plt.title("x*x + y*y = 4")
#plt.savefig('./Downloads/punktverdoppelung.png',dpi=400)

# %%
a = -1
b = 1

y, x = np.ogrid[-5:5:100j, -5:5:100j]
plt.contour(x.ravel(), y.ravel(), pow(x,2)+pow(y,2), [1])
plt.grid()
plt.show()

# %%
a = -2

b = wrongb(a)

x1 = 0.8
y1 = curve(a,b,x1)

m = (3*pow(x1,2) + a)/(2*y1)
t = y1 - m * x1

m2 = -m
t2 = y1 - m2* x1
y, x = np.ogrid[-5:5:100j, -5:5:100j]
plt.contour(x.ravel(), y.ravel(), pow(y, 2) - pow(x, 3) - x * a - b, [0], linewidths=6, colors='black')
plt.plot(x1,y1, marker='o',markersize=15, color='red')
plt.contour(x.ravel(),y.ravel(), y-m*x-t, [0], colors="red")
plt.contour(x.ravel(),y.ravel(), y-m2*x-t2, [0], colors="red")

plt.grid()
plt.show()
